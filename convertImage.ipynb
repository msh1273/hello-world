# %% [markdown]
# <a href="https://colab.research.google.com/github/msh1273/hello-world/blob/master/convertImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /etc/*lease
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.3 LTS"
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !apt update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [819 B]
# Get:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
# !apt install -y imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
# ...

# %%
# !convert
# Out:
# Version: ImageMagick 6.9.7-4 Q16 x86_64 20170114 http://www.imagemagick.org
# Copyright: © 1999-2017 ImageMagick Studio LLC
# License: http://www.imagemagick.org/script/license.php
# Features: Cipher DPC Modules OpenMP
# Delegates (built-in): bzlib djvu fftw fontconfig freetype jbig jng jpeg lcms lqr ltdl lzma openexr pangocairo png tiff wmf x xml zlib
# Usage: convert-im6.q16 [options ...] file [ [options ...] file ...] [options ...] file
#
# Image Settings:
#   -adjoin              join images into a single multi-image file
#   -affine matrix       affine transform matrix
#   -alpha option        activate, deactivate, reset, or set the alpha channel
#   -antialias           remove pixel-aliasing
#   -authenticate password
#                        decipher image with this password
#   -attenuate value     lessen (or intensify) when adding noise to an image
#   -background color    background color
#   -bias value          add bias when convolving an image
# ...

# %%
# !convert wizard.jpg wizard.png
# !convert wizard.jpg wizard.bmp
# Out:
# convert-im6.q16: unable to open image `wizard.jpg': No such file or directory @ error/blob.c/OpenBlob/2701.
# convert-im6.q16: no images defined `wizard.png' @ error/convert.c/ConvertImageCommand/3258.
# convert-im6.q16: unable to open image `wizard.jpg': No such file or directory @ error/blob.c/OpenBlob/2701.
# convert-im6.q16: no images defined `wizard.bmp' @ error/convert.c/ConvertImageCommand/3258.

# %%
# !convert wizard.jpg wizard.png
# Out:
# convert-im6.q16: unable to open image `wizard.jpg': No such file or directory @ error/blob.c/OpenBlob/2701.
# convert-im6.q16: no images defined `wizard.png' @ error/convert.c/ConvertImageCommand/3258.

# %%
# !wget https://imagemagick.org/image/wizard.jpg
# Out:
# --2019-09-24 10:27:54--  https://imagemagick.org/image/wizard.jpg
# Resolving imagemagick.org (imagemagick.org)... 198.72.81.86
# Connecting to imagemagick.org (imagemagick.org)|198.72.81.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23358 (23K) [image/jpeg]
# Saving to: ‘wizard.jpg’
#
# wizard.jpg          100%[===================>]  22.81K  --.-KB/s    in 0.008s
#
# 2019-09-24 10:27:54 (2.80 MB/s) - ‘wizard.jpg’ saved [23358/23358]

# %%
# !convert wizard.jpg wizard.png
# !convert wizard.jpg wizard.bmp

# %%
# !ls -alsh wi*
# Out:
# 276K -rw-r--r-- 1 root root 274K Sep 24 10:28 wizard.bmp
#  24K -rw-r--r-- 1 root root  23K Mar  1  2019 wizard.jpg
#  80K -rw-r--r-- 1 root root  78K Sep 24 10:28 wizard.png

# %%
# !identify -verbose wizard.jpg
# Out:
# Image: wizard.jpg
#   Format: JPEG (Joint Photographic Experts Group JFIF format)
#   Mime type: image/jpeg
#   Class: DirectClass
#   Geometry: 265x352+0+0
#   Resolution: 118x118
#   Print size: 2.24576x2.98305
#   Units: PixelsPerCentimeter
#   Type: TrueColor
#   Endianess: Undefined
#   Colorspace: sRGB
#   Depth: 8-bit
#   Channel depth:
#     red: 8-bit
#     green: 8-bit
#     blue: 8-bit
#   Channel statistics:
#     Pixels: 93280
#     Red:
#       min: 3 (0.0117647)
#       max: 255 (1)
#       mean: 214.982 (0.843066)
#       standard deviation: 71.936 (0.282102)
#       kurtosis: 0.827614
#       skewness: -1.56408
#       entropy: 0.460138
#     Green:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 214.66 (0.841805)
#       standard deviation: 71.7613 (0.281417)
#       kurtosis: 0.785658
#       skewness: -1.54509
#       entropy: 0.475069
#     Blue:
#       min: 0 (0)
#       max: 255 (1)
#       mean: 223.002 (0.874518)
# ...

# %%
# !dentify wizard.jpg
# Out:
# /bin/bash: dentify: command not found

# %%
# !convert wizard.jpg -resize 64X64 wizard_s.jpg

# %%
# !ls -alsh wi*
# Out:
# 276K -rw-r--r-- 1 root root 274K Sep 24 10:28 wizard.bmp
#  24K -rw-r--r-- 1 root root  23K Mar  1  2019 wizard.jpg
#  80K -rw-r--r-- 1 root root  78K Sep 24 10:28 wizard.png
# 4.0K -rw-r--r-- 1 root root 2.0K Sep 24 10:31 wizard_s.jpg

# %%
# !convert wizard.jpg -crop 70X70+100+1000 wizard_c.jpg
# Out:
# convert-im6.q16: geometry does not contain image `wizard.jpg' @ warning/transform.c/CropImage/666.

# %%
# !convert wizard.jpg -crop 70X70+120+120 wizard_c.jpg

# %%
mkdir converted

# %%
# %%bash
# for i in $(ls *.jpg); do
#   convert $i -resize 64X64 converted/$i
#   done
#   ls converted
# Out:
# wizard_c.jpg
# wizard.jpg
# wizard_s.jpg

# %%
# !git clone https://github.com/anishathalye/neural-style.git
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 292, done.
# remote: Total 292 (delta 0), reused 0 (delta 0), pack-reused 292
# Receiving objects: 100% (292/292), 2.63 MiB | 35.87 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# %cd neural-style
# Out:
# /content/neural-style

# %%
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# --2019-09-24 10:51:46--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M  71.1MB/s    in 7.2s
#
# 2019-09-24 10:51:53 (70.5 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# !ls *
# Out:
# imagenet-vgg-verydeep-19.mat  neural_style.py  requirements.txt  vgg.py
# LICENSE.txt		      README.md        stylize.py
#
# examples:
# 1-content.jpg  1-style.jpg    2-output.jpg  2-style2.jpg
# 1-output.jpg   2-content.jpg  2-style1.jpg  tweaks

# %%
# !ls *mat
# Out:
# imagenet-vgg-verydeep-19.mat

# %%
# !git clone https://github.com/anishathalye/neural-style.git
# Out:
# Cloning into 'neural-style'...
# remote: Enumerating objects: 292, done.
# remote: Total 292 (delta 0), reused 0 (delta 0), pack-reused 292
# Receiving objects: 100% (292/292), 2.63 MiB | 36.85 MiB/s, done.
# Resolving deltas: 100% (158/158), done.

# %%
# %cd neural-style
# Out:
# /content/neural-style

# %%
# !wget http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Out:
# --2019-09-24 10:59:57--  http://www.vlfeat.org/matconvnet/models/imagenet-vgg-verydeep-19.mat
# Resolving www.vlfeat.org (www.vlfeat.org)... 64.90.48.57
# Connecting to www.vlfeat.org (www.vlfeat.org)|64.90.48.57|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 534904783 (510M)
# Saving to: ‘imagenet-vgg-verydeep-19.mat’
#
# imagenet-vgg-veryde 100%[===================>] 510.12M   111MB/s    in 4.7s
#
# 2019-09-24 11:00:02 (108 MB/s) - ‘imagenet-vgg-verydeep-19.mat’ saved [534904783/534904783]

# %%
# !ls *mat
# Out:
# imagenet-vgg-verydeep-19.mat

# %%
# !pip install scipy--1.1.0
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement scipy--1.1.0 (from versions: none)
# ERROR: No matching distribution found for scipy--1.1.0

# %%
# !pip install scipy==1.1.0

# %%
# %cd /content/neural-style/
# Out:
# /content/neural-style

# %%
# %cd /content/neural-style/
# !python neural_style.py \
--content ./examples/1-content.jpg     \
--styles ./examples/2-style1.jpg      \
--output ./01.jpg
# Out:
# /content/neural-style
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-24 11:08:29.291753: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-09-24 11:08:29.292008: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x19d32c0 executing computations on platform Host. Devices:
# 2019-09-24 11:08:29.292046: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-09-24 11:08:29.294239: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !wget https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTboT4gzstEWrsiuReu7zglO1p93YmZOPZIch2qXe78uoeKHCpM
# Out:
# --2019-09-24 11:18:32--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTboT4gzstEWrsiuReu7zglO1p93YmZOPZIch2qXe78uoeKHCpM
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 74.125.142.113, 74.125.142.102, 74.125.142.100, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|74.125.142.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11778 (12K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcTboT4gzstEWrsiuReu7zglO1p93YmZOPZIch2qXe78uoeKHCpM’
#
# images?q=tbn:ANd9Gc 100%[===================>]  11.50K  --.-KB/s    in 0s
#
# 2019-09-24 11:18:32 (102 MB/s) - ‘images?q=tbn:ANd9GcTboT4gzstEWrsiuReu7zglO1p93YmZOPZIch2qXe78uoeKHCpM’ saved [11778/11778]

# %%
# !wget https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRX77rmu8uihWV3SsFWRdt_quQ9kIVrR6Qpt8PSCqc-3hSP52WUBA
# Out:
# --2019-09-24 11:20:35--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRX77rmu8uihWV3SsFWRdt_quQ9kIVrR6Qpt8PSCqc-3hSP52WUBA
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 74.125.195.139, 74.125.195.138, 74.125.195.113, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|74.125.195.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5920 (5.8K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcRX77rmu8uihWV3SsFWRdt_quQ9kIVrR6Qpt8PSCqc-3hSP52WUBA’
#
# images?q=tbn:ANd9Gc 100%[===================>]   5.78K  --.-KB/s    in 0s
#
# 2019-09-24 11:20:35 (93.1 MB/s) - ‘images?q=tbn:ANd9GcRX77rmu8uihWV3SsFWRdt_quQ9kIVrR6Qpt8PSCqc-3hSP52WUBA’ saved [5920/5920]

# %%
# !convert /content/neural-style/images?q=tbn:ANd9GcRX77rmu8uihWV3SsFWRdt_quQ9kIVrR6Qpt8PSCqc-3hSP52WUBA ka.jpg
# Out:
# /bin/bash: convert: command not found

# %%
# !wget http://www.mhj21.com/imgdata/mhj21_com/201909/2019090909509193.jpg
# Out:
# --2019-09-24 11:25:05--  http://www.mhj21.com/imgdata/mhj21_com/201909/2019090909509193.jpg
# Resolving www.mhj21.com (www.mhj21.com)... 121.78.144.197
# Connecting to www.mhj21.com (www.mhj21.com)|121.78.144.197|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46929 (46K) [image/jpeg]
# Saving to: ‘2019090909509193.jpg’
#
# 2019090909509193.jp 100%[===================>]  45.83K   158KB/s    in 0.3s
#
# 2019-09-24 11:25:06 (158 KB/s) - ‘2019090909509193.jpg’ saved [46929/46929]

# %%
# %cd /content/neural-style/
# !python neural_style.py \
--content ./2019090909509193.jpg     \
--styles ./examples/2-style2.jpg      \
--output ./02.jpg
# Out:
# /content/neural-style
# WARNING:tensorflow:From /content/neural-style/vgg.py:9: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/neural-style/vgg.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-24 11:26:16.085061: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-09-24 11:26:16.085318: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1fa12c0 executing computations on platform Host. Devices:
# 2019-09-24 11:26:16.085357: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-09-24 11:26:16.087585: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
